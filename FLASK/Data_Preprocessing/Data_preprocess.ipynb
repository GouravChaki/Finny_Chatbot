# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('../CSV_FILES/nasdaq_use.csv')
# df['Last Sale']=df['Last Sale'].astype(float)
df
# Out:
#       Index Symbol                                               Name
# 0      2642  FCNCA  First Citizens BancShares Inc. Class A Common ...  \
# 1      2090    DIS             Walt Disney Company (The) Common Stock
# 2      3149   GNRC                Generac Holdlings Inc. Common Stock
# 3      1379    CCF                     Chase Corporation Common Stock
# 4      2221    DUK  Duke Energy Corporation (Holding Company) Comm...
# ...     ...    ...                                                ...
# 7862   6486  SKYAW                 Skydeck Acquisition Corp. Warrants
# 7863   1510  CHEKZ                    Check-Cap Ltd. Series C Warrant
# 7864   3664  IMACW                         IMAC Holdings Inc. Warrant
# 7865   3252  GSMGW  Glory Star New Media Group Holdings Limited Wa...
# 7866   6014  REVEW             Alpine Acquisition Corporation Warrant
#
#      Last Sale
# 0      $998.86
# 1       $99.97
# 2       $99.80
# 3       $99.75
# 4       $99.74
# ...        ...
# ...

# %%
# # df=df.sort_values(by=['Last Sale'],ascending=False)
# df=df[['Index','Symbol','Name','Last Sale']]
# df.to_csv('./CSV_FILES/nasdaq.csv',index=False)
# df

# %%
print(type(df['Last Sale']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df=df.sort_values(by=['Index'])
df
# Out:
#       Index Symbol                                               Name
# 4820      0      A             Agilent Technologies Inc. Common Stock  \
# 1958      1     AA                    Alcoa Corporation Common Stock
# 5842      2    AAC  Ares Acquisition Corporation Class A Ordinary ...
# 6220      3   AACG   ATA Creativity Global American Depositary Shares
# 6087      4   AACI            Armada Acquisition Corp. I Common Stock
# ...     ...    ...                                                ...
# 6269   7862   ZVSA             ZyVersa Therapeutics Inc. Common Stock
# 3634   7863    ZWS  Zurn Elkay Water Solutions Corporation Common ...
# 174    7864   ZYME                        Zymeworks Inc. Common Stock
# 7170   7865   ZYNE          Zynerba Pharmaceuticals Inc. Common Stock
# 5125   7866   ZYXI                            Zynex Inc. Common Stock
#
#      Last Sale
# 4820   $138.03
# 1958    $39.16
# 5842   $10.325
# 6220     $1.84
# 6087    $10.10
# ...        ...
# ...

# %%
for i in (df['Index'].astype(int)):
    x=df['Last Sale'][i]
    # if(x==0.002):
    #     continue
    # else:
    length=len(x)
    price=x[1:length]
    price=float(price)
    df.loc[i,'Last Sale']=price
    # print(df.loc[i,'Last Sale'])

# %%
# df.to_csv('./CSV_FILES/nasdaq.csv')

# %%
# df=pd.read_csv('./CSV_FILES/nasdaq.csv')

# %%
df
# Out:
#       Index Symbol                                               Name
# 4820      0      A             Agilent Technologies Inc. Common Stock  \
# 1958      1     AA                    Alcoa Corporation Common Stock
# 5842      2    AAC  Ares Acquisition Corporation Class A Ordinary ...
# 6220      3   AACG   ATA Creativity Global American Depositary Shares
# 6087      4   AACI            Armada Acquisition Corp. I Common Stock
# ...     ...    ...                                                ...
# 6269   7862   ZVSA             ZyVersa Therapeutics Inc. Common Stock
# 3634   7863    ZWS  Zurn Elkay Water Solutions Corporation Common ...
# 174    7864   ZYME                        Zymeworks Inc. Common Stock
# 7170   7865   ZYNE          Zynerba Pharmaceuticals Inc. Common Stock
# 5125   7866   ZYXI                            Zynex Inc. Common Stock
#
#      Last Sale
# 4820    138.03
# 1958     39.16
# 5842    10.325
# 6220      1.84
# 6087      10.1
# ...        ...
# ...

# %%
# df=df[['Index','Symbol','Name','Last Sale']]
# df
# Out:
#       Index Symbol                                               Name
# 0         0      A             Agilent Technologies Inc. Common Stock  \
# 1         1     AA                    Alcoa Corporation Common Stock
# 2         2    AAC  Ares Acquisition Corporation Class A Ordinary ...
# 3         3   AACG   ATA Creativity Global American Depositary Shares
# 4         4   AACI            Armada Acquisition Corp. I Common Stock
# ...     ...    ...                                                ...
# 7862   7862   ZVSA             ZyVersa Therapeutics Inc. Common Stock
# 7863   7863    ZWS  Zurn Elkay Water Solutions Corporation Common ...
# 7864   7864   ZYME                        Zymeworks Inc. Common Stock
# 7865   7865   ZYNE          Zynerba Pharmaceuticals Inc. Common Stock
# 7866   7866   ZYXI                            Zynex Inc. Common Stock
#
#       Last Sale
# 0        138.00
# 1         39.10
# 2         10.32
# 3          1.80
# 4         10.10
# ...         ...
# ...

# %%
# df.to_csv('./CSV_FILES/nasdaq.csv',index=False)

# %%
df=df.sort_values(by=['Last Sale'])
df
# Out:
#       Index Symbol                                               Name
# 7866   6014  REVEW             Alpine Acquisition Corporation Warrant  \
# 7865   3252  GSMGW  Glory Star New Media Group Holdings Limited Wa...
# 7864   3664  IMACW                         IMAC Holdings Inc. Warrant
# 7863   1510  CHEKZ                    Check-Cap Ltd. Series C Warrant
# 7862   6486  SKYAW                 Skydeck Acquisition Corp. Warrants
# ...     ...    ...                                                ...
# 2808    790    AZO                         AutoZone Inc. Common Stock
# 2804   1020   BKNG                 Booking Holdings Inc. Common Stock
# 1965   6354    SEB                  Seaboard Corporation Common Stock
# 1204   5133    NVR                              NVR Inc. Common Stock
# 1541   1165  BRK/A                            Berkshire Hathaway Inc.
#
#      Last Sale
# 7866    0.0022
# 7865     0.006
# 7864    0.0096
# 7863    0.0099
# 7862    0.0115
# ...        ...
# ...

# %%
df.to_csv('../CSV_FILES/nasdaq_use.csv',index=False)
